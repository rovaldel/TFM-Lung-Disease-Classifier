# %% [markdown]
# #Transfer-Learning: VGG16

# %% [markdown]
# #1. Preparación de los datos

# %%
## CARGA DE DATOS
## =============================================================================

# !unrar x 'drive/MyDrive/TFM/Datasets/dataset_undersampling.rar'

# %%
## ACELERACIÓN POR GPU
## =============================================================================

from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 392296661494431380, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11345264640
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 16052164128693531236
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
## Uso de Tensorflow 2.
## =============================================================================

# %tensorflow_version 2.x

# %%
## IMPORTACIÓN DE LAS LIBRERIAS NECESARIAS
## =============================================================================

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models    import Sequential, load_model
from tensorflow.keras.layers    import Add, Dense, Activation, GlobalAveragePooling2D, Dropout 
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix

import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # imprimimos en pantalla el resultado de todos los statements

# %%
## DIRECTORIOS
## =============================================================================

base_dir =  'drive/MyDrive/TFM/Transfer-Learning/VGG16/'
train_dir = 'dataset_undersampling/train'
test_dir  = 'dataset_undersampling/test'

# %%
## GENERADOR DE IMÁGENES (Ayuda a cargar y transformar las imágenes por lotes )
## =============================================================================

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,                 
        target_size = (224, 224), 
        batch_size  = 32,
        shuffle=False,
        color_mode='rgb',
        class_mode  ='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size = (224, 224),
        batch_size  = 32,
        shuffle=False,
        color_mode='rgb',
        class_mode  ='categorical')
# Out:
# Found 13178 images belonging to 4 classes.
# Found 3296 images belonging to 4 classes.

# %% [markdown]
# #2. VGG16 (Modelo Base)

# %%
## DEFINICIÓN DE LA ARQUITECTURA DE LA RED NEURONAL
## =============================================================================

base_model = VGG16(weights="imagenet",
                  include_top=False)

base_model.trainable = False                        

model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, None, None, 512)   14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# =================================================================
# Total params: 14,716,740
# Trainable params: 2,052
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
## ENTRENAMIENTO DEL MODELO
## =============================================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir + 'VGG16_model.h5')

 
def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(train_generator, 
                  epochs=60,
                  validation_data=test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'VGG16_history.npy', history.history)
# Out:
# Epoch 1/60
# 412/412 [==============================] - 171s 325ms/step - loss: 1.0068 - accuracy: 0.5920 - val_loss: 0.8602 - val_accuracy: 0.6462
# Epoch 2/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.7871 - accuracy: 0.6952 - val_loss: 0.7485 - val_accuracy: 0.7121
# Epoch 3/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0
60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.3987 - accuracy: 0.8529 - val_loss: 0.4249 - val_accuracy: 0.8407
# Epoch 52/60
# 412/412 [==============================] - 124s 302ms/step - loss: 0.3979 - accuracy: 0.8541 - val_loss: 0.4259 - val_accuracy: 0.8407
# Epoch 53/60
# 412/412 [==============================] - 125s 302ms/step - loss: 0.3976 - accuracy: 0.8544 - val_loss: 0.4254 - val_accuracy: 0.8450
# Epoch 54/60
# 412/412 [==============================] - 125s 302ms/step - loss: 0.3956 - accuracy: 0.8552 - val_loss: 0.4223 - val_accuracy: 0.8450
# Epoch 55/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.3950 - accuracy: 0.8542 - val_loss: 0.4224 - val_accuracy: 0.8441
# Epoch 56/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.3944 - accuracy: 0.8554 - val_loss: 0.4221 - val_accuracy: 0.8428
# Epoch 57/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.3929 - accuracy: 0.8548 - val_loss: 0.4219 - val_accuracy: 0.8428
# Epoch 58/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.3920 - accuracy: 0.8558 - val_loss: 0.4193 - val_accuracy: 0.8425
# Epoch 59/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.3919 - accuracy: 0.8557 - val_loss: 0.4188 - val_accuracy: 0.8410
# Epoch 60/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.3905 - accuracy: 0.8548 - val_loss: 0.4196 - val_accuracy: 0.8434

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'VGG16_model.h5')
history = np.load(base_dir + 'VGG16_history.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 100s 243ms/step - loss: 0.3897 - accuracy: 0.8570
# 103/103 [==============================] - 25s 243ms/step - loss: 0.4196 - accuracy: 0.8434

# %%
## PREDICCIÓN DEL DATASET DE PRUEBA
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([0, 1, 0, ..., 3, 3, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CATEGORÍAS
## =============================================================================

class_names = val_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualización)
## =============================================================================

import seaborn as sns

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## METRICAS
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.80      0.76      0.78       676
#    Lung_Opacity       0.87      0.86      0.86      1153
#          Normal       0.83      0.86      0.85      1200
# Viral_Pneumonia       0.90      0.92      0.91       267
#
#        accuracy                           0.84      3296
#       macro avg       0.85      0.85      0.85      3296
#    weighted avg       0.84      0.84      0.84      3296

# %% [markdown]
# #3. VGG16 (Modelo Base + 2 capas densas)

# %%
## DEFINICIÓN DE LA ARQUITECTURA DE LA RED NEURONAL
## =============================================================================

base_model = VGG16(weights="imagenet",
                  include_top=False)

base_model.trainable = False                        

model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.4))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, None, None, 512)   14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 15,766,852
# Trainable params: 1,052,164
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
## ENTRENAMIENTO DEL MODELO
## =============================================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir + 'VGG16_Dense_model.h5')

def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(train_generator, 
                  epochs=60,
                  validation_data=test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'VGG16_Dense_history.npy', history.history)
# Out:
# Epoch 1/60
# 412/412 [==============================] - 126s 304ms/step - loss: 0.9667 - accuracy: 0.5951 - val_loss: 0.7850 - val_accuracy: 0.6426
# Epoch 2/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.7704 - accuracy: 0.6885 - val_loss: 0.6184 - val_accuracy: 0.7558
# Epoch 3/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.7165 - accuracy: 0.7146 - val_loss: 0.5770 - val_accuracy: 0.7992
# Epoch 4/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6836 - accuracy: 0.7264 - val_loss: 0.5819 - val_accuracy: 0.7967
# Epoch 5/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6740 - accuracy: 0.7270 - val_loss: 0.5536 - val_accuracy: 0.8007
# Epoch 6/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6571 - accuracy: 0.7374 - val_loss: 0.5726 - val_accuracy: 0.7676
# Epoch 7/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6481 - accuracy: 0.7395 - val_loss: 0.5288 - val_accuracy: 0.8098
# Epoch 8/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6325 - accuracy: 0.7481 - val_loss: 0.5158 - val_accuracy: 0.8089
# Epoch 9/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6255 - accuracy: 0.7474 - val_loss: 0.4862 - val_accuracy: 0.8119
# Epoch 10/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6229 - accuracy: 0.7512 - val_loss: 0.5158 - val_accuracy: 0.7985
# Epoch 11/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6175 - accuracy: 0.7536 - val_loss: 0.4984 - val_accuracy: 0.8219
# Epoch 12/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.6098 - accuracy: 0.7581 - val_loss: 0.5286 - val_accuracy: 0.7882
# Epoch 13/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5992 - accuracy: 0.7592 - val_loss: 0.4805 - val_accuracy: 0.8219
# Epoch 14/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5954 - accuracy: 0.7654 - val_loss: 0.4876 - val_accuracy: 0.8231
# Epoch 15/60
# 412/412 [==============================] - 125s 302ms/step - loss: 0.5962 - accuracy: 0.7619 - val_loss: 0.4947 - val_accuracy: 0.8183
# Epoch 16/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5954 - accuracy: 0.7604 - val_loss: 0.5519 - val_accuracy: 0.7864
# Epoch 17/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0
60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5306 - accuracy: 0.7907 - val_loss: 0.4216 - val_accuracy: 0.8441
# Epoch 45/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5366 - accuracy: 0.7883 - val_loss: 0.4385 - val_accuracy: 0.8456
# Epoch 46/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5243 - accuracy: 0.7898 - val_loss: 0.4315 - val_accuracy: 0.8407
# Epoch 47/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5299 - accuracy: 0.7899 - val_loss: 0.4490 - val_accuracy: 0.8310
# Epoch 48/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5298 - accuracy: 0.7904 - val_loss: 0.4277 - val_accuracy: 0.8525
# Epoch 49/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5260 - accuracy: 0.7941 - val_loss: 0.4399 - val_accuracy: 0.8410
# Epoch 50/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5210 - accuracy: 0.7928 - val_loss: 0.4223 - val_accuracy: 0.8456
# Epoch 51/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5235 - accuracy: 0.7920 - val_loss: 0.4253 - val_accuracy: 0.8438
# Epoch 52/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5227 - accuracy: 0.7935 - val_loss: 0.4323 - val_accuracy: 0.8346
# Epoch 53/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5200 - accuracy: 0.7949 - val_loss: 0.4289 - val_accuracy: 0.8422
# Epoch 54/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5192 - accuracy: 0.7934 - val_loss: 0.4261 - val_accuracy: 0.8383
# Epoch 55/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5205 - accuracy: 0.7932 - val_loss: 0.4213 - val_accuracy: 0.8419
# Epoch 56/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5183 - accuracy: 0.7981 - val_loss: 0.4142 - val_accuracy: 0.8483
# Epoch 57/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5183 - accuracy: 0.7946 - val_loss: 0.4395 - val_accuracy: 0.8371
# Epoch 58/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5154 - accuracy: 0.7981 - val_loss: 0.4264 - val_accuracy: 0.8434
# Epoch 59/60
# 412/412 [==============================] - 125s 303ms/step - loss: 0.5139 - accuracy: 0.7951 - val_loss: 0.4158 - val_accuracy: 0.8419
# Epoch 60/60
# 412/412 [==============================] - 125s 304ms/step - loss: 0.5115 - accuracy: 0.7972 - val_loss: 0.4136 - val_accuracy: 0.8471

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'VGG16_Dense_model.h5')
history = np.load(base_dir + 'VGG16_Dense_history.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 101s 245ms/step - loss: 0.3799 - accuracy: 0.8550
# 103/103 [==============================] - 25s 244ms/step - loss: 0.4136 - accuracy: 0.8471

# %%
## PREDICCIÓN DEL MODELO
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([0, 1, 3, ..., 3, 2, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CATEGORÍAS
## =============================================================================

class_names = test_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualización)
## =============================================================================

import seaborn as sns

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## Métricas
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.89      0.67      0.77       676
#    Lung_Opacity       0.82      0.88      0.85      1153
#          Normal       0.83      0.90      0.86      1200
# Viral_Pneumonia       0.95      0.91      0.93       267
#
#        accuracy                           0.85      3296
#       macro avg       0.87      0.84      0.85      3296
#    weighted avg       0.85      0.85      0.84      3296

# %% [markdown]
# #4. VGG16 (Modelo Base + 2 capas densas + últimas capas entrenables)

# %%
## DEFINICIÓN DE LA ARQUITECTURA DE LA RED NEURONAL
## =============================================================================

base_model = VGG16(weights="imagenet",
                  include_top=False)

base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
## DESBLOQUEO DE LAS ÚLTIMAS CAPAS CONVOLUCIONALES
## =============================================================================

base_model.trainable = True

set_trainable = False
for layer in base_model.layers:
    if layer.name in ['block5_conv2', 'block5_conv3']:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 4,719,616
# Non-trainable params: 9,995,072
# _________________________________________________________________

# %%
## AÑADIDO DE DOS CAPAS DENSAS
## =============================================================================

model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, None, None, 512)   14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 15,766,852
# Trainable params: 5,771,780
# Non-trainable params: 9,995,072
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss="categorical_crossentropy",
              optimizer='adam',
              metrics=["accuracy"])

# %%
## ENTRENAMIENTO DEL MODELO
## =============================================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir + 'VGG16_Last_Layer_Trainable_model.h5')

def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(train_generator, 
                  epochs=60,
                  validation_data=test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'VGG16_Last_Layer_Trainable_history.npy', history.history)
# Out:
# Epoch 1/60
# 412/412 [==============================] - 171s 325ms/step - loss: 0.6737 - accuracy: 0.7286 - val_loss: 0.3818 - val_accuracy: 0.8529
# Epoch 2/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.3623 - accuracy: 0.8667 - val_loss: 0.2918 - val_accuracy: 0.8911
# Epoch 3/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.2951 - accuracy: 0.8934 - val_loss: 0.2853 - val_accuracy: 0.8981
# Epoch 4/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.2397 - accuracy: 0.9132 - val_loss: 0.3276 - val_accuracy: 0.8759
# Epoch 5/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.2187 - accuracy: 0.9210 - val_loss: 0.4479 - val_accuracy: 0.8504
# Epoch 6/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.2063 - accuracy: 0.9268 - val_loss: 0.2377 - val_accuracy: 0.9187
# Epoch 7/60
# 412/412 [==============================] - 126s 305ms/step - loss: 0.1659 - accuracy: 0.9398 - val_loss: 0.3182 - val_accuracy: 0.9062
# Epoch 8/60
# 412/412 [==============================] - 126s 307ms/step - loss: 0.1572 - accuracy: 0.9447 - val_loss: 0.2364 - val_accuracy: 0.9184
# Epoch 9/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.1308 - accuracy: 0.9536 - val_loss: 0.3497 - val_accuracy: 0.8968
# Epoch 10/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.1171 - accuracy: 0.9580 - val_loss: 0.2926 - val_accuracy: 0.9093
# Epoch 11/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.1141 - accuracy: 0.9590 - val_loss: 0.3668 - val_accuracy: 0.8914
# Epoch 12/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.0932 - accuracy: 0.9678 - val_loss: 0.3207 - val_accuracy: 0.9184
# Epoch 13/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.0825 - accuracy: 0.9715 - val_loss: 0.3745 - val_accuracy: 0.9172
# Epoch 14/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.0847 - accuracy: 0.9716 - val_loss: 0.4347 - val_accuracy: 0.9111
# Epoch 15/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.0577 - accuracy: 0.9816 - val_loss: 0.4669 - val_accuracy: 0.9038
# Epoch 16/60
# Epoch 56/60
# 412/412 [==============================] - 126s 306ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 1.1921 - val_accuracy: 0.8838
# Epoch 57/60
# 412/412 [==============================] - 126s 307ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 1.0842 - val_accuracy: 0.9144
# Epoch 58/60
# 412/412 [==============================] - 126s 307ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.8753 - val_accuracy: 0.9135
# Epoch 59/60
# 412/412 [==============================] - 126s 307ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.8969 - val_accuracy: 0.9141
# Epoch 60/60
# 412/412 [==============================] - 127s 307ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 1.1430 - val_accuracy: 0.9114

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'VGG16_Last_Layer_Trainable_model.h5')
history = np.load(base_dir + 'VGG16_Last_Layer_Trainable_history.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 144s 262ms/step - loss: 0.0148 - accuracy: 0.9962
# 103/103 [==============================] - 25s 241ms/step - loss: 1.1430 - accuracy: 0.9114

# %%
## PREDICCIÓN DEL MODELO
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([0, 1, 0, ..., 3, 3, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CATEGORIAS
## =============================================================================

class_names = test_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualizacion)
## =============================================================================

import seaborn as sns

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## Métricas
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.96      0.88      0.92       676
#    Lung_Opacity       0.88      0.92      0.90      1153
#          Normal       0.90      0.91      0.91      1200
# Viral_Pneumonia       0.98      0.95      0.97       267
#
#        accuracy                           0.91      3296
#       macro avg       0.93      0.92      0.92      3296
#    weighted avg       0.91      0.91      0.91      3296
