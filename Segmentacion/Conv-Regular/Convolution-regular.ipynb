# %% [markdown]
# #MODELO CON SEGMENTACIÓN

# %% [markdown]
# #1. PREPARACIÓN DE LOS DATOS

# %%
## CARGA DE DATOS
## =============================================================================

# !unrar x 'drive/MyDrive/TFM/Datasets/dataset_segmentation.rar'

# %%
## ACELERACIÓN POR GPU
## =============================================================================

from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16554600125540730552, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11344216064
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11249287313210054060
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
## Uso de Tensorflow 2.
## =============================================================================

# %tensorflow_version 2.x

# %%
## IMPORTACIÓN DE LAS LIBRERIAS NECESARIAS
## =============================================================================

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models    import Sequential, load_model
from tensorflow.keras.layers    import Flatten, Dense, Activation, BatchNormalization, Conv2D, MaxPooling2D, Dropout 
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from functools import partial
from tensorflow.keras.regularizers import L2
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.applications import MobileNet

import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # imprime en pantalla el resultado de todos los statements

# %%
# Directorios
base_dir =  'drive/MyDrive/TFM/Segmentacion/Conv-Regular'
train_dir = 'dataset_segmentation/train'
test_dir  = 'dataset_segmentation/test'

# %%
## GENERADOR DE IMÁGENES 'grayscale' (Ayuda a cargar y transformar las imágenes por lotes )
## =============================================================================

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = (224, 224),                 
        batch_size  = 32,
        shuffle=True,
        color_mode='grayscale',
        class_mode  ='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size = (224, 224),
        batch_size  = 32,
        shuffle=True,
        color_mode='grayscale',
        class_mode  = 'categorical')
# Out:
# Found 13178 images belonging to 4 classes.
# Found 3296 images belonging to 4 classes.

# %% [markdown]
# #1. Red convolucional 1

# %%
## DEFINICIÓN DE LA TOPOLOGÍA DE LA RED NEURONAL
## ====================================================

DefaultConv2D = partial(Conv2D,
                         kernel_size=3, 
                         activation='relu',
                         padding='same',
                         strides=1,
                         kernel_regularizer =L2(0.01))

model = Sequential([
    
    # CONV1 Y MAX-POOLING1                           
    DefaultConv2D(filters=32, input_shape=[224, 224, 1]),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV2 & CONV3 Y MAX-POOLING2
    DefaultConv2D(filters=64),
    DefaultConv2D(filters=64),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV4 Y MAX-POOLING3
    DefaultConv2D(filters=64),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV5 Y MAX-POOLING4
    DefaultConv2D(filters=128),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),
   
    # CONV6 Y MAX-POOLING5
    DefaultConv2D(filters=256),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV7 Y MAX-POOLING6
    DefaultConv2D(filters=256),
    MaxPooling2D(pool_size=3),
    BatchNormalization(),

    # APLANADO Y RED CLÁSICA
    Flatten(),
    Dropout(0.4),
    Dense(units=32, activation='relu'),
    Dense(units=4, activation='softmax'),

])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 112, 112, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                32800
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 1,087,908
# Trainable params: 1,086,308
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss='categorical_crossentropy', 
               optimizer= 'adam',
               metrics=['accuracy'])

# %%
## ENTRENAMIENTO DEL MODELO
## =============================================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir +'segmentation.h5')

def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(
                  train_generator,
                  epochs=60,
                  validation_data= test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'segmentation.npy', history.history)
# Out:
# Epoch 1/60
# 412/412 [==============================] - 100s 166ms/step - loss: 4.4511 - accuracy: 0.6635 - val_loss: 5.3345 - val_accuracy: 0.2051
# Epoch 2/60
# 412/412 [==============================] - 66s 160ms/step - loss: 1.4284 - accuracy: 0.7214 - val_loss: 2.3078 - val_accuracy: 0.2667
# Epoch 3/60
# 412/412 [==============================] - 66s 159ms/step - loss: 1.1181 - accuracy: 0.7319 - val_loss: 1.3201 - val_accuracy: 0.7005
# Epoch 4/60
# 412/412 [==============================] - 65s 159ms/step - loss: 1.0406 - accuracy: 0.7484 - val_loss: 1.2660 - val_accuracy: 0.6353
# Epoch 5/60
# 412/412 [==============================] - 65s 158ms/step - loss: 0.9979 - accuracy: 0.7536 - val_loss: 1.4065 - val_accuracy: 0.5343
# Epoch 6/60
# 412/412 [==============================] - 65s 158ms/step - loss: 1.0034 - accuracy: 0.7605 - val_loss: 1.3487 - val_accuracy: 0.6214
# Epoch 7/60
# 412/412 [==============================] - 65s 158ms/step - loss: 0.9796 - accuracy: 0.7585 - val_loss: 1.7177 - val_accuracy: 0.4399
# Epoch 8/60
# 412/412 [==============================] - 65s 158ms/step - loss: 0.9376 - accuracy: 0.7675 - val_loss: 1.1482 - val_accuracy: 0.7093
# Epoch 9/60
# 412/412 [==============================] - 65s 158ms/step - loss: 0.9338 - accuracy: 0.7739 - val_loss: 1.8252 - val_accuracy: 0.4879
# Epoch 10/60
# 412/412 [==============================] - 65s 157ms/step - loss: 0.9259 - accuracy: 0.7770 - val_loss: 1.4928 - val_accuracy: 0.4970
# Epoch 11/60
# 412/412 [==============================] - 65s 156ms/step - loss: 0.9058 - accuracy: 0.7812 - val_loss: 1.4563 - val_accuracy: 0.5819
# Epoch 12/60
# 412/412 [==============================] - 65s 157ms/step - loss: 0.8997 - accuracy: 0.7820 - val_loss: 1.2485 - val_accuracy: 0.6432
# Epoch 13/60
# 412/412 [==============================] - 64s 156ms/step - loss: 0.8738 - accuracy: 0.7937 - val_loss: 1.8543 - val_accuracy: 0.4721
# Epoch 14/60
# Epoch 54/60
# 412/412 [==============================] - 64s 155ms/step - loss: 0.4588 - accuracy: 0.9152 - val_loss: 1.3921 - val_accuracy: 0.7285
# Epoch 55/60
# 412/412 [==============================] - 64s 155ms/step - loss: 0.4563 - accuracy: 0.9154 - val_loss: 0.9245 - val_accuracy: 0.7985
# Epoch 56/60
# 412/412 [==============================] - 64s 156ms/step - loss: 0.4484 - accuracy: 0.9160 - val_loss: 4.0575 - val_accuracy: 0.4272
# Epoch 57/60
# 412/412 [==============================] - 64s 155ms/step - loss: 0.4697 - accuracy: 0.9092 - val_loss: 0.8836 - val_accuracy: 0.7982
# Epoch 58/60
# 412/412 [==============================] - 64s 155ms/step - loss: 0.4403 - accuracy: 0.9193 - val_loss: 0.7326 - val_accuracy: 0.8383
# Epoch 59/60
# 412/412 [==============================] - 64s 155ms/step - loss: 0.4506 - accuracy: 0.9168 - val_loss: 0.7896 - val_accuracy: 0.8271
# Epoch 60/60
# 412/412 [==============================] - 64s 156ms/step - loss: 0.4376 - accuracy: 0.9216 - val_loss: 0.8943 - val_accuracy: 0.8034

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'segmentation.h5')
history = np.load(base_dir + 'segmentation.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 64s 87ms/step - loss: 0.5919 - accuracy: 0.8648
# 103/103 [==============================] - 9s 84ms/step - loss: 0.8943 - accuracy: 0.8034

# %%
## PREDICCIÓN DEL DATASET DE PRUEBA
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([1, 1, 2, ..., 3, 3, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CATEGORÍAS
## =============================================================================

class_names = test_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualización)
## ======================================================

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## METRICAS
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.91      0.50      0.65       676
#    Lung_Opacity       0.84      0.81      0.83      1153
#          Normal       0.73      0.96      0.83      1200
# Viral_Pneumonia       0.95      0.80      0.87       267
#
#        accuracy                           0.80      3296
#       macro avg       0.86      0.77      0.79      3296
#    weighted avg       0.82      0.80      0.80      3296

# %% [markdown]
# ##2. Aumento de filtros convolucionales (red convolucional 4)

# %%
## DEFINICIÓN DE LA TOPOLOGÍA DE LA RED NEURONAL
## ====================================================

DefaultConv2D = partial(Conv2D,
                         kernel_size=3, 
                         activation='relu',
                         padding='same',
                         strides=1,
                         kernel_regularizer =L2(0.01))

model = Sequential([
    
    # CONV1 Y MAX-POOLING1                           
    DefaultConv2D(filters=32, input_shape=[224, 224, 1]),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV2 & CONV3 Y MAX-POOLING2
    DefaultConv2D(filters=64),
    DefaultConv2D(filters=64),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV4 & CONV5 Y MAX-POOLING3
    DefaultConv2D(filters=64),
    DefaultConv2D(filters=64),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV6 & CONV7 Y MAX-POOLING4
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),
   
    # CONV8 & CONV9 Y MAX-POOLING5
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV10 & CONV11 Y MAX-POOLING6
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    MaxPooling2D(pool_size=3),
    BatchNormalization(),

    # APLANADO Y RED CLÁSICA
    Flatten(),
    Dropout(0.4),
    Dense(units=32, activation='relu'),
    Dense(units=4, activation='softmax'),

])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 32)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 112, 112, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        36928
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 256)       590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                32800
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 2,452,580
# Trainable params: 2,450,980
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss='categorical_crossentropy', 
               optimizer= 'adam',
               metrics=['accuracy'])

# %%
## ENTRENAMIENTO DEL MODELO
## =============================================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir +'model_MoreConv.h5')

def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(
                  train_generator,
                  epochs=60,
                  validation_data= test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'history_MoreConv.npy', history.history)
# Out:
# Epoch 1/60
# 412/412 [==============================] - 111s 191ms/step - loss: 7.7687 - accuracy: 0.6594 - val_loss: 4.8588 - val_accuracy: 0.2051
# Epoch 2/60
# 412/412 [==============================] - 76s 185ms/step - loss: 1.8545 - accuracy: 0.6983 - val_loss: 1.8923 - val_accuracy: 0.3656
# Epoch 3/60
# 412/412 [==============================] - 76s 185ms/step - loss: 1.1392 - accuracy: 0.7126 - val_loss: 1.2872 - val_accuracy: 0.6174
# Epoch 4/60
# 412/412 [==============================] - 76s 185ms/step - loss: 0.9773 - accuracy: 0.7154 - val_loss: 1.0463 - val_accuracy: 0.6693
# Epoch 5/60
# 412/412 [==============================] - 76s 185ms/step - loss: 0.9025 - accuracy: 0.7283 - val_loss: 1.2914 - val_accuracy: 0.5995
# Epoch 6/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.8631 - accuracy: 0.7414 - val_loss: 1.2271 - val_accuracy: 0.5695
# Epoch 7/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.8173 - accuracy: 0.7503 - val_loss: 1.0637 - val_accuracy: 0.6617
# Epoch 8/60
# 412/412 [==============================] - 76s 185ms/step - loss: 0.7919 - accuracy: 0.7554 - val_loss: 0.8739 - val_accuracy: 0.7291
# Epoch 9/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.7605 - accuracy: 0.7677 - val_loss: 0.9253 - val_accuracy: 0.7242
# Epoch 10/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.7353 - accuracy: 0.7759 - val_loss: 0.8399 - val_accuracy: 0.7451
# Epoch 11/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.7128 - accuracy: 0.7799 - val_loss: 0.7686 - val_accuracy: 0.7427
# Epoch 12/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.6789 - accuracy: 0.7941 - val_loss: 2.0694 - val_accuracy: 0.4885
# Epoch 13/60
# 412/412 [==============================] - 76s 185ms/step - loss: 0.6767 - accuracy: 0.7950 - val_loss: 0.8872 - val_accuracy: 0.6996
# Epoch 14/60
# 412/412 [==============================] - 76s 185ms/step - loss: 0.6594 - accuracy: 0.8019 - val_loss: 0.8706 - val_accuracy: 0.6908
# Epoch 15/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.6389 - accuracy: 0.8054 - val_loss: 0.7989 - val_accuracy: 0.7254
# Epoch 16/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.6342 - accuracy: 0.8114 - val_loss: 1.2875 - val_accuracy: 0.5306
# Epoch 17/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.6203 - accuracy: 0.8136 - val_loss: 1.2707 - val_accuracy: 0.6001
# Epoch 18/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.6175 - accuracy: 0.8156 - val_loss: 0.8460 - val_accuracy: 0.7282
# Epoch 19/60
# 412/412 [==============================] - 76s 184ms/step - loss: 0.6031 - accuracy: 0.8208 - val_loss: 0.8322 - val_accuracy: 0.6966
# 412/412 [==============================] - 75s 183ms/step - loss: 0.4242 - accuracy: 0.8881 - val_loss: 1.1231 - val_accuracy: 0.6823
# Epoch 60/60
# 412/412 [==============================] - 76s 183ms/step - loss: 0.4238 - accuracy: 0.8840 - val_loss: 1.5345 - val_accuracy: 0.5840

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'model_MoreConv.h5')
history = np.load(base_dir + 'history_MoreConv.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO 
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 34s 81ms/step - loss: 1.3634 - accuracy: 0.6109
# 103/103 [==============================] - 8s 80ms/step - loss: 1.5345 - accuracy: 0.5840

# %%
## PREDICCIÓN DEL MODELO
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CAREGORIAS
## =============================================================================

class_names = test_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualización)
## ======================================================

import seaborn as sns

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## Métricas
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.54      0.90      0.68       676
#    Lung_Opacity       0.56      0.80      0.66      1153
#          Normal       1.00      0.12      0.21      1200
# Viral_Pneumonia       0.68      0.96      0.79       267
#
#        accuracy                           0.58      3296
#       macro avg       0.69      0.69      0.58      3296
#    weighted avg       0.72      0.58      0.51      3296

# %% [markdown]
# #3. Aumento de filtros en las primeras capas (red convolucional 2)

# %%
## DEFINICIÓN DE LA TOPOLOGÍA DE LA RED NEURONAL
## =============================================================================

DefaultConv2D = partial(Conv2D,
                         kernel_size=3, 
                         activation='relu',
                         padding='same',
                         strides=1,
                         kernel_regularizer =L2(0.01))

model = Sequential([
    
    # CONV1 Y MAX-POOLING1                           
    DefaultConv2D(filters=32, input_shape=[224, 224, 1]),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV2 & CONV3 Y MAX-POOLING2
    DefaultConv2D(filters=64),
    DefaultConv2D(filters=64),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV4 & CONV5 Y MAX-POOLING3
    DefaultConv2D(filters=64),
    DefaultConv2D(filters=64),
    DefaultConv2D(filters=64),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV6 & CONV7 Y MAX-POOLING4
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),
   
    # CONV8 & CONV9 Y MAX-POOLING5
    DefaultConv2D(filters=256),
    MaxPooling2D(pool_size=2),
    BatchNormalization(),

    # CONV10 & CONV11 Y MAX-POOLING6
    DefaultConv2D(filters=256),
    MaxPooling2D(pool_size=3),
    BatchNormalization(),

    # APLANADO Y RED CLÁSICA
    Flatten(),
    Dropout(0.4),
    Dense(units=32, activation='relu'),
    Dense(units=4, activation='softmax'),

])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 224, 224, 32)      320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 112, 112, 32)      128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 112, 112, 64)      18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 7, 256)         1024
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                32800
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 1,456,932
# Trainable params: 1,455,332
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss='categorical_crossentropy', 
               optimizer= 'adam',
               metrics=['accuracy'])

# %%
## ENTRENAMIENTO DEL MODELO
## =============================================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir +'first_MoreConv.h5')

def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(
                  train_generator,
                  epochs=60,
                  validation_data= test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'history_firstConv.npy', history.history)
# Out:
# Epoch 1/60
# 412/412 [==============================] - 115s 206ms/step - loss: 6.5760 - accuracy: 0.6556 - val_loss: 7.9448 - val_accuracy: 0.2051
# Epoch 2/60
# 412/412 [==============================] - 83s 200ms/step - loss: 1.9387 - accuracy: 0.6854 - val_loss: 2.6173 - val_accuracy: 0.4038
# Epoch 3/60
# 412/412 [==============================] - 82s 200ms/step - loss: 1.2555 - accuracy: 0.6977 - val_loss: 1.2674 - val_accuracy: 0.6614
# 412/412 [==============================] - 81s 196ms/step - loss: 0.5633 - accuracy: 0.8563 - val_loss: 0.8246 - val_accuracy: 0.7436
# Epoch 44/60
# 412/412 [==============================] - 81s 196ms/step - loss: 0.5495 - accuracy: 0.8590 - val_loss: 1.0585 - val_accuracy: 0.7242
# Epoch 45/60
# 412/412 [==============================] - 81s 196ms/step - loss: 0.5532 - accuracy: 0.8562 - val_loss: 1.2249 - val_accuracy: 0.6599
# Epoch 46/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5431 - accuracy: 0.8625 - val_loss: 0.9281 - val_accuracy: 0.7124
# Epoch 47/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5410 - accuracy: 0.8629 - val_loss: 0.7580 - val_accuracy: 0.7721
# Epoch 48/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5413 - accuracy: 0.8618 - val_loss: 0.8133 - val_accuracy: 0.7746
# Epoch 49/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5284 - accuracy: 0.8666 - val_loss: 1.0275 - val_accuracy: 0.6781
# Epoch 50/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5256 - accuracy: 0.8667 - val_loss: 0.7573 - val_accuracy: 0.7928
# Epoch 51/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5254 - accuracy: 0.8694 - val_loss: 1.1368 - val_accuracy: 0.6678
# Epoch 52/60
# 412/412 [==============================] - 81s 196ms/step - loss: 0.5184 - accuracy: 0.8697 - val_loss: 0.9688 - val_accuracy: 0.7188
# Epoch 53/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5191 - accuracy: 0.8711 - val_loss: 0.7861 - val_accuracy: 0.7688
# Epoch 54/60
# 412/412 [==============================] - 81s 197ms/step - loss: 0.5063 - accuracy: 0.8750 - val_loss: 0.6886 - val_accuracy: 0.8004
# Epoch 55/60
# 412/412 [==============================] - 81s 196ms/step - loss: 0.5009 - accuracy: 0.8787 - val_loss: 1.6204 - val_accuracy: 0.5604
# Epoch 56/60
# 412/412 [==============================] - 81s 196ms/step - loss: 0.5021 - accuracy: 0.8734 - val_loss: 0.7294 - val_accuracy: 0.8016
# Epoch 57/60
# 412/412 [==============================] - 80s 195ms/step - loss: 0.4983 - accuracy: 0.8796 - val_loss: 1.9406 - val_accuracy: 0.4842
# Epoch 58/60
# 412/412 [==============================] - 80s 195ms/step - loss: 0.5054 - accuracy: 0.8788 - val_loss: 0.9791 - val_accuracy: 0.7479
# Epoch 59/60
# 412/412 [==============================] - 80s 195ms/step - loss: 0.5025 - accuracy: 0.8795 - val_loss: 1.2068 - val_accuracy: 0.7042
# Epoch 60/60
# 412/412 [==============================] - 81s 196ms/step - loss: 0.4892 - accuracy: 0.8834 - val_loss: 0.6214 - val_accuracy: 0.8337

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'first_MoreConv.h5')
history = np.load(base_dir + 'history_firstConv.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 63s 87ms/step - loss: 0.4512 - accuracy: 0.8992
# 103/103 [==============================] - 9s 87ms/step - loss: 0.6214 - accuracy: 0.8337

# %%
## PREDICCIÓN DEL MODELO
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([1, 1, 2, ..., 3, 3, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CATEGORIAS
## =============================================================================

class_names = test_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualización)
## ======================================================

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## Métricas
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.81      0.75      0.78       676
#    Lung_Opacity       0.84      0.84      0.84      1153
#          Normal       0.84      0.86      0.85      1200
# Viral_Pneumonia       0.80      0.93      0.86       267
#
#        accuracy                           0.83      3296
#       macro avg       0.83      0.84      0.83      3296
#    weighted avg       0.83      0.83      0.83      3296

# %% [markdown]
# #4. Transfer-Learning: MobileNet (Modelo Base + 2 capas densas + últimas capas entrenables)

# %%
## GENERADOR DE IMÁGENES 'rgb' (Ayuda a cargar y transformar las imágenes por lotes )
## =============================================================================

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,                 
        target_size = (224, 224), 
        batch_size  = 32,
        shuffle=False,
        color_mode='rgb',
        class_mode  ='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size = (224, 224),
        batch_size  = 32,
        shuffle=False,
        color_mode='rgb',
        class_mode  = 'categorical')
# Out:
# Found 13178 images belonging to 4 classes.
# Found 3296 images belonging to 4 classes.

# %%
## DEFINICIÓN DE LA ARQUITECTURA DE LA RED NEURONAL
## =============================================================================

base_model = MobileNet(weights="imagenet",
                  include_top=False)

base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# conv1 (Conv2D)               (None, None, None, 32)    864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, None, None, 32)    128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, None, None, 32)    0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, None, None, 32)    288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, None, None, 32)    128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, None, None, 32)    0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, None, None, 64)    2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, None, None, 64)    256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, None, None, 64)    0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, None, None, 64)    0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, None, None, 64)    576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, None, None, 64)    256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, None, None, 64)    0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, None, None, 128)   8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, None, None, 128)   1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, None, None, 128)   16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, None, None, 128)   0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, None, None, 128)   1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, None, None, 128)   512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, None, None, 128)   0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, None, None, 256)   32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, None, None, 256)   2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, None, None, 256)   65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, None, None, 256)   0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, None, None, 256)   2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, None, None, 256)   1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, None, None, 256)   0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, None, None, 512)   131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, None, None, 512)   262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, None, None, 512)   0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, None, None, 512)   4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, None, None, 512)   2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, None, None, 512)   0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, None, None, 1024)  524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, None, None, 1024)  0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, None, None, 1024)  9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, None, None, 1024)  0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, None, None, 1024)  1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, None, None, 1024)  4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, None, None, 1024)  0
# =================================================================
# Total params: 3,228,864
# Trainable params: 3,206,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
## DESBLOQUEO DE ÚLTIMAS CAPAS ENTRENABLES
## =============================================================================

base_model.trainable = True

set_trainable = False
for layer in base_model.layers:
    if layer.name in ['conv_pw_13', 'conv_pw_13_bn']:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
## AÑADIDO DE 2 CAPAS DENSAS
## =============================================================================

model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, None, None, 1024)  3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 4,805,316
# Trainable params: 2,627,076
# Non-trainable params: 2,178,240
# _________________________________________________________________

# %%
## COMPILACIÓN DEL MODELO
## =============================================================================

model.compile(loss="categorical_crossentropy",
              optimizer='SGD',
              metrics=["accuracy"])

# %%
## ENTRENAMIENTO DEL MODELO
## ======================================================

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

checkpoint_cb  = ModelCheckpoint(base_dir + 'MobileNet_Last_Layer_Trainable_model.h5')

def scheduler(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * tf.math.exp(0.01 * (10 - epoch))

callback_LRS = LearningRateScheduler(scheduler)

history = model.fit(train_generator, 
                  epochs=100,
                  validation_data=test_generator,
                  callbacks=[checkpoint_cb, callback_LRS])

# Guardado del histórico para su posterior recuperación 
np.save(base_dir + 'MobileNet_Last_Layer_Trainable_history.npy', history.history)
# Out:
# Epoch 1/100
# 412/412 [==============================] - 55s 130ms/step - loss: 1.1208 - accuracy: 0.5352 - val_loss: 0.7830 - val_accuracy: 0.6857
# Epoch 2/100
# 412/412 [==============================] - 53s 128ms/step - loss: 0.8648 - accuracy: 0.6496 - val_loss: 0.6829 - val_accuracy: 0.7312
# Epoch 3/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.7880 - accuracy: 0.6812 - val_loss: 0.6433 - val_accuracy: 0.7479
# Epoch 4/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.7366 - accuracy: 0.7063 - val_loss: 0.6092 - val_accuracy: 0.7703
# Epoch 5/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.7073 - accuracy: 0.7179 - val_loss: 0.5936 - val_accuracy: 0.7725
# Epoch 6/100
# 412/412 [==============================] - 54s 130ms/step - loss: 0.6768 - accuracy: 0.7277 - val_loss: 0.5838 - val_accuracy: 0.7712
# Epoch 7/100
# 412/412 [==============================] - 54s 130ms/step - loss: 0.6554 - accuracy: 0.7378 - val_loss: 0.5642 - val_accuracy: 0.7828
# Epoch 8/100
# 412/412 [==============================] - 53s 129ms/step - loss: 0.6389 - accuracy: 0.7465 - val_loss: 0.5544 - val_accuracy: 0.7888
# Epoch 9/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.6162 - accuracy: 0.7519 - val_loss: 0.5451 - val_accuracy: 0.7934
# Epoch 10/100
# 412/412 [==============================] - 54s 130ms/step - loss: 0.6027 - accuracy: 0.7591 - val_loss: 0.5381 - val_accuracy: 0.7961
# Epoch 11/100
# 412/412 [==============================] - 53s 129ms/step - loss: 0.5979 - accuracy: 0.7589 - val_loss: 0.5317 - val_accuracy: 0.7964
# Epoch 12/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.5839 - accuracy: 0.7736 - val_loss: 0.5261 - val_accuracy: 0.7976
# Epoch 13/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.5749 - accuracy: 0.7750 - val_loss: 0.5189 - val_accuracy: 0.8013
# Epoch 14/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.5593 - accuracy: 0.7796 - val_loss: 0.5136 - val_accuracy: 0.8025
# Epoch 15/100
# 412/412 [==============================] - 53s 129ms/step - loss: 0.5547 - accuracy: 0.7817 - val_loss: 0.5084 - val_accuracy: 0.8064
# Epoch 16/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.5428 - accuracy: 0.7854 - val_loss: 0.5073 - val_accuracy: 0.8061
# Epoch 17/100
# 412/412 [==============================] - 54s 130ms/step - loss: 0.5415 - accuracy: 0.7850 - val_loss: 0.5009 - val_accuracy: 0.8067
# Epoch 18/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.5421 - accuracy: 0.7824 - val_loss: 0.4983 - val_accuracy: 0.8092
# Epoch 19/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.5288 - accuracy: 0.7928 - val_loss: 0.4931 - val_accuracy: 0.8104
# Epoch 20/100
# 412/412 [==============================] - 53s 129ms/step - loss: 0
100
# 412/412 [==============================] - 53s 129ms/step - loss: 0.3088 - accuracy: 0.8803 - val_loss: 0.4261 - val_accuracy: 0.8444
# Epoch 95/100
# 412/412 [==============================] - 53s 128ms/step - loss: 0.3101 - accuracy: 0.8854 - val_loss: 0.4259 - val_accuracy: 0.8459
# Epoch 96/100
# 412/412 [==============================] - 53s 128ms/step - loss: 0.2997 - accuracy: 0.8899 - val_loss: 0.4257 - val_accuracy: 0.8434
# Epoch 97/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.3010 - accuracy: 0.8859 - val_loss: 0.4256 - val_accuracy: 0.8450
# Epoch 98/100
# 412/412 [==============================] - 53s 129ms/step - loss: 0.3011 - accuracy: 0.8870 - val_loss: 0.4253 - val_accuracy: 0.8459
# Epoch 99/100
# 412/412 [==============================] - 53s 130ms/step - loss: 0.3004 - accuracy: 0.8877 - val_loss: 0.4263 - val_accuracy: 0.8456
# Epoch 100/100
# 412/412 [==============================] - 53s 129ms/step - loss: 0.3020 - accuracy: 0.8845 - val_loss: 0.4251 - val_accuracy: 0.8450

# %%
## RECUPERACIÓN DEL MODELO E HISTÓRICO
## =============================================================================

model   = load_model(base_dir + 'MobileNet_Last_Layer_Trainable_model.h5')
history = np.load(base_dir + 'MobileNet_Last_Layer_Trainable_history.npy', allow_pickle='TRUE').item()

# %%
del history['lr']

# %%
## REPRESENTACIÓN GRÁFICA
## =============================================================================

pd.DataFrame(history).plot(figsize=(8, 5))
plt.title('epochs vs accuracy & loss')
plt.xlabel('epochs')
plt.ylabel('accuray & loss')
#plt.ylim(0,1)
plt.grid(True)
plt.savefig(base_dir + 'learning_curves_model');

# %%
## EVALUACIÓN DEL MODELO
## =============================================================================

result_train = model.evaluate(train_generator)
result_test = model.evaluate(test_generator)
# Out:
# 412/412 [==============================] - 43s 103ms/step - loss: 0.2094 - accuracy: 0.9307
# 103/103 [==============================] - 11s 102ms/step - loss: 0.4251 - accuracy: 0.8450

# %%
## PREDICCIÓN DEL DATASET DE PRUEBA
## =============================================================================

y_pred = np.argmax(model.predict(test_generator), axis=1)
y_pred
# Out:
# array([0, 1, 3, ..., 3, 3, 3])

# %%
## MATRIZ DE CONFUSIÓN
## =============================================================================

y_test  = test_generator.classes
confusion = confusion_matrix(y_test, y_pred)

# %%
## CATEGORÍAS
## =============================================================================

class_names = test_generator.class_indices.keys()
class_names
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral_Pneumonia'])

# %%
## MATRIZ DE CONFUSIÓN (Visualización)
## ======================================================

import seaborn as sns

cm = pd.DataFrame(confusion, range(4), range(4))

plt.figure(figsize = (12,10))
sns.heatmap(cm, annot=True, 
             fmt='.4g',
             annot_kws   = {"size": 15},
             cbar_kws    = {"shrink": .8},
             xticklabels = class_names, 
             yticklabels = class_names);
plt.xlabel("Predicted values")
plt.ylabel("Actual values");

# %%
## METRICAS
## =============================================================================

print(classification_report(test_generator.classes, y_pred, target_names=class_names));
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.81      0.73      0.77       676
#    Lung_Opacity       0.84      0.86      0.85      1153
#          Normal       0.86      0.88      0.87      1200
# Viral_Pneumonia       0.89      0.90      0.90       267
#
#        accuracy                           0.84      3296
#       macro avg       0.85      0.84      0.85      3296
#    weighted avg       0.84      0.84      0.84      3296
